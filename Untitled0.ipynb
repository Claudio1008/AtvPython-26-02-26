# %% [markdown]
# <a href="https://colab.research.google.com/github/Claudio1008/AtvPython-26-02-26/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nota = int(input("DIGITE SUA NOTA DE 0 A 10 , QUANTO VC GOSTOU DO SUCO"))
if nota < 5:
  print("nao gotei")
elif nota >=5 and nota <= 7:
  print("esta bom mas da pra melhorar")
elif nota > 7 and nota <= 9:
  print("muito bom")
else :
  print("suco exelente")

# %%
TempoCorrida = float(input("DIGITE O TEMPO DA CORRIDA: "))

if TempoCorrida <= 10:
  print("A CORRIDA FICOU 10 REAIS")
elif TempoCorrida > 10 and TempoCorrida <=20:
  valorCorrida = 1.20 * TempoCorrida
  print(f"SUA CORRIDA FICOU {valorCorrida:.2f} REAIS")
else:
  valorCorrida = 1.00 * TempoCorrida
  print(f"SUA CORRIDA FICOU {valorCorrida:.2f} REAIS")

# %%
idade = int(input("DIGITE A IDADE: "))
estudante = input("VC É ESTUDANDE (S/N)").upper()
valor = 30

if estudante == "S" or estudante == "Sim" :
  desconto = valor/100 * 70
  print(f"o valor do seu ingresso é {desconto} REAIS")
elif idade <= 13 or idade >= 60:
  desconto = valor/100 * 50
  print(f"o valor do ingresso é {desconto} REAIS")
else:
  print(f"o valor do ingresso é {valor} REAIS")
# Out:
# DIGITE A IDADE: 20
# VC É ESTUDANDE (S/N)nso
# o valor do ingresso é 30 REAIS

# %%
idade = int(input("DIGITE A IDADE: "))
estudante = input("VC É ESTUDANDE: (S/N) ou sim/nao")
valor = 30

if idade < 12 or idade > 60:
  valor *= 0.5
elif estudante.lower() == 's' or 'sim':
  valor *= 0.7
print(f"o valor do ingresso é R${valor:.2f} ")
# Out:
# DIGITE A IDADE: 20
# VC É ESTUDANDE: (S/N) ou sim/naon
# o valor do ingresso é R$21.00

# %%
# Out:
# DIGITE A IDADE: 20
# VC É ESTUDANDE (S/N): sim
# o valor do seu ingresso é 21.0 REAIS
